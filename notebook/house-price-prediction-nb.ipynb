# %% [markdown]
# # House Price Prediction with Linear Regression
# Predicting house prices using linear regression involves creating a model that estimates the relationship between house prices and various features

# %% [markdown]
# ## Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Data Analysis

# %%
dataframe = pd.read_csv('../data/data.csv')
dataframe.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
dataframe.shape
# Out:
# (4600, 18)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
#  17  country        4600 non-null   object
# dtypes: float64(4), int64(9), object(5)
# memory usage: 647.0+ KB

# %%
dataframe.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# min       1.000000     0.000000     0.000000     1.000000   370.000000
# 25%       1.000000     0.000000     0.000000     3.000000  1190.000000
# 50%       1.500000     0.000000     0.000000     3.000000  1590.000000
# 75%       2.000000     0.000000     0.000000     4.000000  2300.000000
# max       3.500000     1.000000     4.000000     5.000000  9410.000000
#
#        sqft_basement     yr_built  yr_renovated
# count    4600.000000  4600.000000   4600.000000
# mean      312.081522  1970.786304    808.608261
# std       464.137228    29.731848    979.414536
# min         0.000000  1900.000000      0.000000
# 25%         0.000000  1951.000000      0.000000
# 50%         0.000000  1976.000000      0.000000
# 75%       610.000000  1997.000000   1999.000000
# max      4820.000000  2014.000000   2014.000000

# %%
dataframe['view'].value_counts()
# Out:
# view
# 0    4140
# 2     205
# 3     116
# 4      70
# 1      69
# Name: count, dtype: int64

# %%
dataframe['waterfront'].value_counts()
# Out:
# waterfront
# 0    4567
# 1      33
# Name: count, dtype: int64

# %%
dataframe['condition'].value_counts()
# Out:
# condition
# 3    2875
# 4    1252
# 5     435
# 2      32
# 1       6
# Name: count, dtype: int64

# %%
dataframe['street'].value_counts()
# Out:
# street
# 2520 Mulberry Walk NE     4
# 2500 Mulberry Walk NE     3
# 9413 34th Ave SW          2
# 6008 8th Ave NE           2
# 11034 NE 26th Pl          2
#                          ..
# 1404 Broadmoor Dr E       1
# 3249 E Ames Lake Dr NE    1
# 6032 35th Ave NE          1
# 1006 NE Ravenna Blvd      1
# 18717 SE 258th St         1
# Name: count, Length: 4525, dtype: int64

# %%
dataframe['city'].value_counts().shape
# Out:
# (44,)

# %%
dataframe['statezip'].value_counts()
# Out:
# statezip
# WA 98103    148
# WA 98052    135
# WA 98117    132
# WA 98115    130
# WA 98006    110
#            ...
# WA 98047      6
# WA 98288      3
# WA 98050      2
# WA 98354      2
# WA 98068      1
# Name: count, Length: 77, dtype: int64

# %%
dataframe['country'].value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %%
dataframe.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
dataframe.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %% [markdown]
# ## Dropping Some Columns
# * Drop Date
# * Drop View
# * Drop Street
# * Drop City
# * Drop Statezip
# * Drop Country
# * Drop Sqft Basement
# * Drop Year Renovated

# %%
new_dataframe = dataframe.drop(columns=['date','view','street','city','statezip','country','sqft_basement','yr_renovated'])
new_dataframe
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  condition  sqft_above  yr_built
# 0              0          3        1340      1955
# 1              0          5        3370      1921
# 2              0          4        1930      1966
# 3              0          4        1000      1963
# 4              0          4        1140      1976
# ...          ...        ...         ...       ...
# 4595           0          4        1510      1954
# 4596           0          3        1460      1983
# 4597           0          3        3010      2009
# 4598           0          3        1070      1974
# 4599           0          4        1490      1990
#
# [4600 rows x 10 columns]

# %%
new_dataframe.shape
# Out:
# (4600, 10)

# %%
new_dataframe.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    condition  sqft_above  yr_built
# 0          3        1340      1955
# 1          5        3370      1921
# 2          4        1930      1966
# 3          4        1000      1963
# 4          4        1140      1976

# %% [markdown]
# ## Checking if there's a zero values in selected columns

# %%
zero_check = new_dataframe.iloc[:,-2:]
zero_check
# Out:
#       sqft_above  yr_built
# 0           1340      1955
# 1           3370      1921
# 2           1930      1966
# 3           1000      1963
# 4           1140      1976
# ...          ...       ...
# 4595        1510      1954
# 4596        1460      1983
# 4597        3010      2009
# 4598        1070      1974
# 4599        1490      1990
#
# [4600 rows x 2 columns]

# %%
(zero_check == 0).sum()
# Out:
# sqft_above    0
# yr_built      0
# dtype: int64

# %%
(new_dataframe['price'] == 0).sum()
# Out:
# 49

# %% [markdown]
# ## Re-assigning Zero Values in Price

# %%
new_dataframe.loc[new_dataframe['price'] == 0, 'price'] = new_dataframe['price'].median()

# %%
(new_dataframe['price'] == 0).sum()
# Out:
# 0

# %%
new_dataframe.shape
# Out:
# (4600, 10)

# %%
new_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        4600 non-null   float64
#  1   bedrooms     4600 non-null   float64
#  2   bathrooms    4600 non-null   float64
#  3   sqft_living  4600 non-null   int64
#  4   sqft_lot     4600 non-null   int64
#  5   floors       4600 non-null   float64
#  6   waterfront   4600 non-null   int64
#  7   condition    4600 non-null   int64
#  8   sqft_above   4600 non-null   int64
#  9   yr_built     4600 non-null   int64
# dtypes: float64(4), int64(6)
# memory usage: 359.5 KB

# %%
new_dataframe.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.568730e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.610060e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    7.800000e+03     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.281589e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609717e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront    condition   sqft_above     yr_built
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     3.451739  1827.265435  1970.786304
# std       0.538288     0.084404     0.677230   862.168977    29.731848
# min       1.000000     0.000000     1.000000   370.000000  1900.000000
# 25%       1.000000     0.000000     3.000000  1190.000000  1951.000000
# 50%       1.500000     0.000000     3.000000  1590.000000  1976.000000
# 75%       2.000000     0.000000     4.000000  2300.000000  1997.000000
# max       3.500000     1.000000     5.000000  9410.000000  2014.000000

# %% [markdown]
# ## Convert into integer all the values in floor to make it appropriate

# %%
new_dataframe['floors'] = new_dataframe['floors'].astype(int)

# %% [markdown]
# ## Converting Price Notation into Thousands

# %%
new_dataframe['price'] = (new_dataframe['price'] / 1_000)
new_dataframe
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      313.000000       3.0       1.50         1340      7912       1
# 1     2384.000000       5.0       2.50         3650      9050       2
# 2      342.000000       3.0       2.00         1930     11947       1
# 3      420.000000       3.0       2.25         2000      8030       1
# 4      550.000000       4.0       2.50         1940     10500       1
# ...           ...       ...        ...          ...       ...     ...
# 4595   308.166667       3.0       1.75         1510      6360       1
# 4596   534.333333       3.0       2.50         1460      7573       2
# 4597   416.904167       3.0       2.50         3010      7014       2
# 4598   203.400000       4.0       2.00         2090      6630       1
# 4599   220.600000       3.0       2.50         1490      8102       2
#
#       waterfront  condition  sqft_above  yr_built
# 0              0          3        1340      1955
# 1              0          5        3370      1921
# 2              0          4        1930      1966
# 3              0          4        1000      1963
# 4              0          4        1140      1976
# ...          ...        ...         ...       ...
# 4595           0          4        1510      1954
# 4596           0          3        1460      1983
# 4597           0          3        3010      2009
# 4598           0          3        1070      1974
# 4599           0          4        1490      1990
#
# [4600 rows x 10 columns]

# %%
new_dataframe.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count   4600.000000  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean     556.873038     3.400870     2.160815   2139.346957  1.485252e+04
# std      561.005967     0.908848     0.783781    963.206916  3.588444e+04
# min        7.800000     0.000000     0.000000    370.000000  6.380000e+02
# 25%      328.158929     3.000000     1.750000   1460.000000  5.000750e+03
# 50%      460.971731     3.000000     2.250000   1980.000000  7.683000e+03
# 75%      654.962500     4.000000     2.500000   2620.000000  1.100125e+04
# max    26590.000000     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront    condition   sqft_above     yr_built
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.459130     0.007174     3.451739  1827.265435  1970.786304
# std       0.552194     0.084404     0.677230   862.168977    29.731848
# min       1.000000     0.000000     1.000000   370.000000  1900.000000
# 25%       1.000000     0.000000     3.000000  1190.000000  1951.000000
# 50%       1.000000     0.000000     3.000000  1590.000000  1976.000000
# 75%       2.000000     0.000000     4.000000  2300.000000  1997.000000
# max       3.000000     1.000000     5.000000  9410.000000  2014.000000

# %%
new_dataframe.shape
# Out:
# (4600, 10)

# %% [markdown]
# ## Assigning the Features and Target (X and y)

# %%
# FEATURES
X = new_dataframe.drop(columns=['price'])
X
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0          3.0       1.50         1340      7912       1           0
# 1          5.0       2.50         3650      9050       2           0
# 2          3.0       2.00         1930     11947       1           0
# 3          3.0       2.25         2000      8030       1           0
# 4          4.0       2.50         1940     10500       1           0
# ...        ...        ...          ...       ...     ...         ...
# 4595       3.0       1.75         1510      6360       1           0
# 4596       3.0       2.50         1460      7573       2           0
# 4597       3.0       2.50         3010      7014       2           0
# 4598       4.0       2.00         2090      6630       1           0
# 4599       3.0       2.50         1490      8102       2           0
#
#       condition  sqft_above  yr_built
# 0             3        1340      1955
# 1             5        3370      1921
# 2             4        1930      1966
# 3             4        1000      1963
# 4             4        1140      1976
# ...         ...         ...       ...
# 4595          4        1510      1954
# 4596          3        1460      1983
# 4597          3        3010      2009
# 4598          3        1070      1974
# 4599          4        1490      1990
#
# [4600 rows x 9 columns]

# %%
X.shape
# Out:
# (4600, 9)

# %%
# TARGET
y = new_dataframe['price']
y
# Out:
# 0        313.000000
# 1       2384.000000
# 2        342.000000
# 3        420.000000
# 4        550.000000
#            ...
# 4595     308.166667
# 4596     534.333333
# 4597     416.904167
# 4598     203.400000
# 4599     220.600000
# Name: price, Length: 4600, dtype: float64

# %% [markdown]
# ## Splitting Dataset (Training Data and Testing Data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Object Creation

# %%
linear_model = LinearRegression()

# %% [markdown]
# ## Model Training

# %%
linear_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction

# %%
linear_model_prediction = linear_model.predict(X_test)
linear_model_prediction
# Out:
# array([ 505.78573057,  638.97419777,  218.66216671, ..., 1035.93340343,
#         318.52383988,  351.0045642 ])

# %%
r2 = r2_score(y_test, linear_model_prediction)
r2
# Out:
# 0.09661866014406917
